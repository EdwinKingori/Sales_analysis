# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import datetime

# %% [markdown]
# #### Merging 12 months sales data into a single cell

# %%
df = pd.read_csv("./Sales_Data/Sales_April_2019.csv")

files = [file for file in os.listdir('./Sales_Data')]

merged_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("./Sales_Data/"+ file)
    merged_data = pd.concat([merged_data, df])
    
merged_data.to_csv("merged_data.csv", index=False)

# %% [markdown]
# #### Reading the updated dataframe

# %%
merged_data = pd.read_csv('merged_data.csv')
merged_data.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ##### Displaying cells/rows with nan values

# %%
nan_df = merged_data[merged_data.isnull().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 198       NaN     NaN              NaN        NaN        NaN              NaN
# 574       NaN     NaN              NaN        NaN        NaN              NaN
# 776       NaN     NaN              NaN        NaN        NaN              NaN
# 1383      NaN     NaN              NaN        NaN        NaN              NaN
# 1436      NaN     NaN              NaN        NaN        NaN              NaN

# %%
merged_data = merged_data.dropna(how='all')
merged_data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        248151   AA Batteries (4-pack)                4       3.84
# 1        248152    USB-C Charging Cable                2      11.95
# 2        248153    USB-C Charging Cable                1      11.95
# 3        248154        27in FHD Monitor                1     149.99
# 4        248155    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   150497            20in Monitor                1     109.99
# 186846   150498        27in FHD Monitor                1     149.99
# 186847   150499         ThinkPad Laptop                1     999.99
# 186848   150500  AAA Batteries (4-pack)                2       2.99
# 186849   150501            Google Phone                1        600
#
#             Order Date                       Purchase Address
# 0       09/17/19 14:44    380 North St, Los Angeles, CA 90001
# 1       09/29/19 10:19           511 8th St, Austin, TX 73301
# 2       09/16/19 17:48  151 Johnson St, Los Angeles, CA 90001
# 3       09/27/19 07:52      355 Hickory St, Seattle, WA 98101
# 4       09/01/19 19:03          125 5th St, Atlanta, GA 30301
# ...                ...                                    ...
# 186845  01/26/19 19:09            95 8th St, Dallas, TX 75001
# 186846  01/10/19 22:58    403 7th St, San Francisco, CA 94016
# 186847  01/21/19 14:31        214 Main St, Portland, OR 97035
# 186848  01/15/19 14:21      810 2nd St, Los Angeles, CA 90001
# 186849  01/13/19 16:43         428 Cedar St, Boston, MA 02215
#
# [186305 rows x 6 columns]

# %% [markdown]
# #### Spliting the 'Order Date' column into Month and Time columns

# %%
# Convert 'Order Date' column from object to datetime
merged_data[ 'Order Date'] = pd.to_datetime(merged_data['Order Date'], errors='coerce')
# Add a month column
merged_data.loc[:,'Month'] = merged_data['Order Date'].dt.month
#Add a time column
merged_data.loc[:,'Time'] = merged_data['Order Date'].dt.time
merged_data.head()
# Out:
# /tmp/ipykernel_13294/3202776783.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   merged_data[ 'Order Date'] = pd.to_datetime(merged_data['Order Date'], errors='coerce')
#   Order ID                Product Quantity Ordered Price Each  \
# 0   248151  AA Batteries (4-pack)                4       3.84
# 1   248152   USB-C Charging Cable                2      11.95
# 2   248153   USB-C Charging Cable                1      11.95
# 3   248154       27in FHD Monitor                1     149.99
# 4   248155   USB-C Charging Cable                1      11.95
#
#            Order Date                       Purchase Address  Month      Time
# 0 2019-09-17 14:44:00    380 North St, Los Angeles, CA 90001    9.0  14:44:00
# 1 2019-09-29 10:19:00           511 8th St, Austin, TX 73301    9.0  10:19:00
# 2 2019-09-16 17:48:00  151 Johnson St, Los Angeles, CA 90001    9.0  17:48:00
# 3 2019-09-27 07:52:00      355 Hickory St, Seattle, WA 98101    9.0  07:52:00
# 4 2019-09-01 19:03:00          125 5th St, Atlanta, GA 30301    9.0  19:03:00

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
#  6   Month             185950 non-null  float64
#  7   Time              185950 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 12.8+ MB

# %%
#checking nan value in the Month column created
nan_values = merged_data[merged_data['Month'].isna()]
nan_values
# Out:
#         Order ID  Product  Quantity Ordered  Price Each Order Date  \
# 1679    Order ID  Product  Quantity Ordered  Price Each        NaT
# 3732    Order ID  Product  Quantity Ordered  Price Each        NaT
# 3790    Order ID  Product  Quantity Ordered  Price Each        NaT
# 4323    Order ID  Product  Quantity Ordered  Price Each        NaT
# 5579    Order ID  Product  Quantity Ordered  Price Each        NaT
# ...          ...      ...               ...         ...        ...
# 183633  Order ID  Product  Quantity Ordered  Price Each        NaT
# 184671  Order ID  Product  Quantity Ordered  Price Each        NaT
# 184801  Order ID  Product  Quantity Ordered  Price Each        NaT
# 185398  Order ID  Product  Quantity Ordered  Price Each        NaT
# 186438  Order ID  Product  Quantity Ordered  Price Each        NaT
#
#         Purchase Address  Month Time
# 1679    Purchase Address    NaN  NaN
# 3732    Purchase Address    NaN  NaN
# 3790    Purchase Address    NaN  NaN
# 4323    Purchase Address    NaN  NaN
# 5579    Purchase Address    NaN  NaN
# ...                  ...    ...  ...
# 183633  Purchase Address    NaN  NaN
# 184671  Purchase Address    NaN  NaN
# 184801  Purchase Address    NaN  NaN
# 185398  Purchase Address    NaN  NaN
# 186438  Purchase Address    NaN  NaN
#
# [355 rows x 8 columns]

# %%
# Cleaning by removing the NaN & Natvalues from the month column
merged_data.dropna(subset=['Month'], inplace=True)

# Resetting the DataFrame index
merged_data.reset_index(drop=True, inplace=True)

# %%
# Confirming the contents of the specified row with indexing
df = merged_data.loc[merged_data.index == 3732]
print(df)
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 3732   251749  34in Ultrawide Monitor                1     379.99
#
#               Order Date                  Purchase Address  Month      Time
# 3732 2019-09-15 13:25:00  512 Jackson St, Dallas, TX 75001    9.0  13:25:00

# %%
# Dropping the row from the Merged dataframe
merged_data.drop(3732, inplace=True)

# %%
# Converting the Month column to an integer.  
merged_data[ 'Month'] = merged_data['Month'].astype('int32')

# %%
#Confirming the data types of the month and time columns
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185949 entries, 0 to 185949
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185949 non-null  object
#  1   Product           185949 non-null  object
#  2   Quantity Ordered  185949 non-null  object
#  3   Price Each        185949 non-null  object
#  4   Order Date        185949 non-null  datetime64[ns]
#  5   Purchase Address  185949 non-null  object
#  6   Month             185949 non-null  int32
#  7   Time              185949 non-null  object
# dtypes: datetime64[ns](1), int32(1), object(6)
# memory usage: 12.1+ MB

# %% [markdown]
# ### Data Exploration
# Solving the main business questions related to the data
# ### Task A.  What was the best month of sales? How much was earned that month?

# %%
merged_data.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each  \
# 0   248151  AA Batteries (4-pack)                4       3.84
# 1   248152   USB-C Charging Cable                2      11.95
# 2   248153   USB-C Charging Cable                1      11.95
# 3   248154       27in FHD Monitor                1     149.99
# 4   248155   USB-C Charging Cable                1      11.95
#
#            Order Date                       Purchase Address  Month      Time
# 0 2019-09-17 14:44:00    380 North St, Los Angeles, CA 90001      9  14:44:00
# 1 2019-09-29 10:19:00           511 8th St, Austin, TX 73301      9  10:19:00
# 2 2019-09-16 17:48:00  151 Johnson St, Los Angeles, CA 90001      9  17:48:00
# 3 2019-09-27 07:52:00      355 Hickory St, Seattle, WA 98101      9  07:52:00
# 4 2019-09-01 19:03:00          125 5th St, Atlanta, GA 30301      9  19:03:00

# %% [markdown]
# ##### Adding a sales column

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185949 entries, 0 to 185949
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185949 non-null  object
#  1   Product           185949 non-null  object
#  2   Quantity Ordered  185949 non-null  object
#  3   Price Each        185949 non-null  object
#  4   Order Date        185949 non-null  datetime64[ns]
#  5   Purchase Address  185949 non-null  object
#  6   Month             185949 non-null  int32
#  7   Time              185949 non-null  object
# dtypes: datetime64[ns](1), int32(1), object(6)
# memory usage: 12.1+ MB

# %% [markdown]
# #### Converting Sales and Quantity ordered columns to the correct data types

# %%
merged_data['Price Each'] = pd.to_numeric(merged_data['Price Each'])
merged_data['Quantity Ordered'] = pd.to_numeric(merged_data['Quantity Ordered'])

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185949 entries, 0 to 185949
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185949 non-null  object
#  1   Product           185949 non-null  object
#  2   Quantity Ordered  185949 non-null  int64
#  3   Price Each        185949 non-null  float64
#  4   Order Date        185949 non-null  datetime64[ns]
#  5   Purchase Address  185949 non-null  object
#  6   Month             185949 non-null  int32
#  7   Time              185949 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(4)
# memory usage: 12.1+ MB

# %%
merged_data['Total sales'] = merged_data['Quantity Ordered'] * merged_data['Price Each']
merged_data.head(10)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   248151     AA Batteries (4-pack)                 4        3.84
# 1   248152      USB-C Charging Cable                 2       11.95
# 2   248153      USB-C Charging Cable                 1       11.95
# 3   248154          27in FHD Monitor                 1      149.99
# 4   248155      USB-C Charging Cable                 1       11.95
# 5   248156    34in Ultrawide Monitor                 1      379.99
# 6   248157  Lightning Charging Cable                 1       14.95
# 7   248158  Lightning Charging Cable                 1       14.95
# 8   248159           Vareebadd Phone                 1      400.00
# 9   248160          Wired Headphones                 1       11.99
#
#            Order Date                        Purchase Address  Month  \
# 0 2019-09-17 14:44:00     380 North St, Los Angeles, CA 90001      9
# 1 2019-09-29 10:19:00            511 8th St, Austin, TX 73301      9
# 2 2019-09-16 17:48:00   151 Johnson St, Los Angeles, CA 90001      9
# 3 2019-09-27 07:52:00       355 Hickory St, Seattle, WA 98101      9
# 4 2019-09-01 19:03:00           125 5th St, Atlanta, GA 30301      9
# 5 2019-09-13 14:59:00      469 12th St, Los Angeles, CA 90001      9
# 6 2019-09-07 09:59:00      773 Johnson St, Portland, ME 04101      9
# 7 2019-09-02 14:16:00    682 Sunset St, Los Angeles, CA 90001      9
# 8 2019-09-06 16:45:00  664 Wilson St, New York City, NY 10001      9
# 9 2019-09-01 22:03:00     446 9th St, San Francisco, CA 94016      9
#
#        Time  Total sales
# 0  14:44:00        15.36
# 1  10:19:00        23.90
# 2  17:48:00        11.95
# 3  07:52:00       149.99
# 4  19:03:00        11.95
# 5  14:59:00       379.99
# 6  09:59:00        14.95
# 7  14:16:00        14.95
# 8  16:45:00       400.00
# 9  22:03:00        11.99

# %%
# Checking the best month of sales & the amount earned in that month
#Task1: Groupby month

best_month = merged_data.groupby('Month').agg({
    'Quantity Ordered': 'sum',
    'Total sales': 'sum'
}).reset_index()
best_month
# Out:
#     Month  Quantity Ordered  Total sales
# 0       1             10903   1822256.73
# 1       2             13449   2202022.42
# 2       3             17005   2807100.38
# 3       4             20558   3390670.24
# 4       5             18667   3152606.75
# 5       6             15253   2577802.26
# 6       7             16072   2647775.76
# 7       8             13448   2244467.88
# 8       9             13108   2097180.14
# 9      10             22703   3736726.88
# 10     11             19798   3199603.20
# 11     12             28114   4613443.34

# %%
# setting the best_month df in descending order
best_month.sort_values(by='Total sales', ascending=False)
# Out:
#     Month  Quantity Ordered  Total sales
# 11     12             28114   4613443.34
# 9      10             22703   3736726.88
# 3       4             20558   3390670.24
# 10     11             19798   3199603.20
# 4       5             18667   3152606.75
# 2       3             17005   2807100.38
# 6       7             16072   2647775.76
# 5       6             15253   2577802.26
# 7       8             13448   2244467.88
# 1       2             13449   2202022.42
# 8       9             13108   2097180.14
# 0       1             10903   1822256.73

# %% [markdown]
# #### Visualizing the Task A results

# %%
months = range(1,13)
print(months)
plt.bar(months, best_month['Total sales'], color="#008fd5", linewidth=4, edgecolor='black')
plt.xticks(months)

#removing scientific notation
#plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.ticklabel_format(style='plain') 


plt.style.use('fivethirtyeight')
plt.grid(color= 'green', linestyle = '-')
plt.ylabel("Sales in USD($)")
plt.xlabel("Months")
plt.title('Sales by Month')
# Out:
# range(1, 13)
# Text(0.5, 1.0, 'Sales by Month')

# %% [markdown]
# ### Task A Results:
# #### What was the best month of sales? December
# #### How much was earned that month? $4613443.34

# %% [markdown]
# ## Task B: What city sold the most product?

# %%
merged_data.head(10)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   248151     AA Batteries (4-pack)                 4        3.84
# 1   248152      USB-C Charging Cable                 2       11.95
# 2   248153      USB-C Charging Cable                 1       11.95
# 3   248154          27in FHD Monitor                 1      149.99
# 4   248155      USB-C Charging Cable                 1       11.95
# 5   248156    34in Ultrawide Monitor                 1      379.99
# 6   248157  Lightning Charging Cable                 1       14.95
# 7   248158  Lightning Charging Cable                 1       14.95
# 8   248159           Vareebadd Phone                 1      400.00
# 9   248160          Wired Headphones                 1       11.99
#
#            Order Date                        Purchase Address  Month  \
# 0 2019-09-17 14:44:00     380 North St, Los Angeles, CA 90001      9
# 1 2019-09-29 10:19:00            511 8th St, Austin, TX 73301      9
# 2 2019-09-16 17:48:00   151 Johnson St, Los Angeles, CA 90001      9
# 3 2019-09-27 07:52:00       355 Hickory St, Seattle, WA 98101      9
# 4 2019-09-01 19:03:00           125 5th St, Atlanta, GA 30301      9
# 5 2019-09-13 14:59:00      469 12th St, Los Angeles, CA 90001      9
# 6 2019-09-07 09:59:00      773 Johnson St, Portland, ME 04101      9
# 7 2019-09-02 14:16:00    682 Sunset St, Los Angeles, CA 90001      9
# 8 2019-09-06 16:45:00  664 Wilson St, New York City, NY 10001      9
# 9 2019-09-01 22:03:00     446 9th St, San Francisco, CA 94016      9
#
#        Time  Total sales
# 0  14:44:00        15.36
# 1  10:19:00        23.90
# 2  17:48:00        11.95
# 3  07:52:00       149.99
# 4  19:03:00        11.95
# 5  14:59:00       379.99
# 6  09:59:00        14.95
# 7  14:16:00        14.95
# 8  16:45:00       400.00
# 9  22:03:00        11.99

# %% [markdown]
# ### Steps
# #### Step 1: Extract the location from the purchase address column and store the data in a new location column.
# #### Step 2: Groupby and get the sum aggregate of the city column.
# #### Step 3: Visualize the data to exhibit the city with the most sales.

# %%
# Step 1
merged_data['City'] = [x.split(',')[1] for x in merged_data['Purchase Address'].values]
merged_data.head(10)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   248151     AA Batteries (4-pack)                 4        3.84
# 1   248152      USB-C Charging Cable                 2       11.95
# 2   248153      USB-C Charging Cable                 1       11.95
# 3   248154          27in FHD Monitor                 1      149.99
# 4   248155      USB-C Charging Cable                 1       11.95
# 5   248156    34in Ultrawide Monitor                 1      379.99
# 6   248157  Lightning Charging Cable                 1       14.95
# 7   248158  Lightning Charging Cable                 1       14.95
# 8   248159           Vareebadd Phone                 1      400.00
# 9   248160          Wired Headphones                 1       11.99
#
#            Order Date                        Purchase Address  Month  \
# 0 2019-09-17 14:44:00     380 North St, Los Angeles, CA 90001      9
# 1 2019-09-29 10:19:00            511 8th St, Austin, TX 73301      9
# 2 2019-09-16 17:48:00   151 Johnson St, Los Angeles, CA 90001      9
# 3 2019-09-27 07:52:00       355 Hickory St, Seattle, WA 98101      9
# 4 2019-09-01 19:03:00           125 5th St, Atlanta, GA 30301      9
# 5 2019-09-13 14:59:00      469 12th St, Los Angeles, CA 90001      9
# 6 2019-09-07 09:59:00      773 Johnson St, Portland, ME 04101      9
# 7 2019-09-02 14:16:00    682 Sunset St, Los Angeles, CA 90001      9
# 8 2019-09-06 16:45:00  664 Wilson St, New York City, NY 10001      9
# 9 2019-09-01 22:03:00     446 9th St, San Francisco, CA 94016      9
#
#        Time  Total sales            City
# 0  14:44:00        15.36     Los Angeles
# 1  10:19:00        23.90          Austin
# 2  17:48:00        11.95     Los Angeles
# 3  07:52:00       149.99         Seattle
# 4  19:03:00        11.95         Atlanta
# 5  14:59:00       379.99     Los Angeles
# 6  09:59:00        14.95        Portland
# 7  14:16:00        14.95     Los Angeles
# 8  16:45:00       400.00   New York City
# 9  22:03:00        11.99   San Francisco

# %%
merged_data['City'] = [x.split(',')[1] + ', ' + x.split(',')[2].split(' ')[1] for x in merged_data['Purchase Address'].values]
merged_data.head(10)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   248151     AA Batteries (4-pack)                 4        3.84
# 1   248152      USB-C Charging Cable                 2       11.95
# 2   248153      USB-C Charging Cable                 1       11.95
# 3   248154          27in FHD Monitor                 1      149.99
# 4   248155      USB-C Charging Cable                 1       11.95
# 5   248156    34in Ultrawide Monitor                 1      379.99
# 6   248157  Lightning Charging Cable                 1       14.95
# 7   248158  Lightning Charging Cable                 1       14.95
# 8   248159           Vareebadd Phone                 1      400.00
# 9   248160          Wired Headphones                 1       11.99
#
#            Order Date                        Purchase Address  Month  \
# 0 2019-09-17 14:44:00     380 North St, Los Angeles, CA 90001      9
# 1 2019-09-29 10:19:00            511 8th St, Austin, TX 73301      9
# 2 2019-09-16 17:48:00   151 Johnson St, Los Angeles, CA 90001      9
# 3 2019-09-27 07:52:00       355 Hickory St, Seattle, WA 98101      9
# 4 2019-09-01 19:03:00           125 5th St, Atlanta, GA 30301      9
# 5 2019-09-13 14:59:00      469 12th St, Los Angeles, CA 90001      9
# 6 2019-09-07 09:59:00      773 Johnson St, Portland, ME 04101      9
# 7 2019-09-02 14:16:00    682 Sunset St, Los Angeles, CA 90001      9
# 8 2019-09-06 16:45:00  664 Wilson St, New York City, NY 10001      9
# 9 2019-09-01 22:03:00     446 9th St, San Francisco, CA 94016      9
#
#        Time  Total sales                City
# 0  14:44:00        15.36     Los Angeles, CA
# 1  10:19:00        23.90          Austin, TX
# 2  17:48:00        11.95     Los Angeles, CA
# 3  07:52:00       149.99         Seattle, WA
# 4  19:03:00        11.95         Atlanta, GA
# 5  14:59:00       379.99     Los Angeles, CA
# 6  09:59:00        14.95        Portland, ME
# 7  14:16:00        14.95     Los Angeles, CA
# 8  16:45:00       400.00   New York City, NY
# 9  22:03:00        11.99   San Francisco, CA

# %%
# Step 2 :grouping data by city and getting the sum column
df_results = merged_data.groupby('City')[['Quantity Ordered', 'Price Each','Month', 'Total sales']].sum()
df_results
# Out:
#                     Quantity Ordered  Price Each   Month  Total sales
# City
#  Atlanta, GA                   16602  2779908.20  104794   2795498.58
#  Austin, TX                    11153  1809873.61   69829   1819581.75
#  Boston, MA                    22528  3637409.77  141112   3661642.01
#  Dallas, TX                    16729  2752247.83  104611   2767595.41
#  Los Angeles, CA               33289  5421435.23  208325   5452570.80
#  New York City, NY             27932  4635370.83  175741   4664317.43
#  Portland, ME                   2750   447189.25   17144    449758.27
#  Portland, OR                  11303  1860558.22   70621   1870732.34
#  San Francisco, CA             50239  8211461.74  315520   8262203.91
#  Seattle, WA                   16553  2733296.01  104941   2747755.48

# %%
# Step 3 Visualizing 
Cities = df_results.index
Total_Sales = df_results['Total sales']
plt.bar(Cities, Total_Sales, color="#008fd5", linewidth=4, edgecolor='black')
plt.xticks(Cities, rotation=90, ha = 'right')

#plt.ticklabel_format(style='plain')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

plt.style.use('fivethirtyeight')
plt.grid(color= 'green', linestyle = '-')
plt.xlabel('City')
plt.ylabel('Total sales')
plt.title('Total Sales per City')
# Out:
# Text(0.5, 1.0, 'Total Sales per City')

# %%
#Create a stacked-barchart where each bar represents a city, and the segments within each bar represent the contribution of each month to the total sales for that city.

# %%
#Using boxplot to visualize the distribution of total sales between cities
sns.set(style="darkgrid")

Cities = df_results.index
Total_Sales = df_results['Total sales']
plot = sns.boxplot(data = df_results,x=Total_Sales, y=Cities, orient='h', )

plt.gcf().axes[0].xaxis.get_major_formatter().set_scientific(False)
plt.xticks( rotation=90, ha = 'right')

plt.xlabel('Total Sales (in USD)')
plt.ylabel('City')
plt.title('Distribution of Total Sales by City')
# Out:
# Text(0.5, 1.0, 'Distribution of Total Sales by City')

# %% [markdown]
# #### Task 3 Results: ( What city sold the most product?)
# #### San Francisco, CA

# %% [markdown]
# ### Task 4: What time should we display advertisements to maximize the likelihood of customer’s buying product?

# %% [markdown]
# #### Step 1: Extracting the hours from the Order Date column and placing it into an newly created 'Hour' column.
# #### Step 2: Utilizing the "groupby" function to categorize and group the data based on the "hours" column.
# #### Step 3: Create a visualization to exhibit which time periods are mostly utilized to make purchases

# %%
merged_data.head()
# Out:
#   Order ID                Product  Quantity Ordered  Price Each  \
# 0   248151  AA Batteries (4-pack)                 4        3.84
# 1   248152   USB-C Charging Cable                 2       11.95
# 2   248153   USB-C Charging Cable                 1       11.95
# 3   248154       27in FHD Monitor                 1      149.99
# 4   248155   USB-C Charging Cable                 1       11.95
#
#            Order Date                       Purchase Address  Month      Time  \
# 0 2019-09-17 14:44:00    380 North St, Los Angeles, CA 90001      9  14:44:00
# 1 2019-09-29 10:19:00           511 8th St, Austin, TX 73301      9  10:19:00
# 2 2019-09-16 17:48:00  151 Johnson St, Los Angeles, CA 90001      9  17:48:00
# 3 2019-09-27 07:52:00      355 Hickory St, Seattle, WA 98101      9  07:52:00
# 4 2019-09-01 19:03:00          125 5th St, Atlanta, GA 30301      9  19:03:00
#
#    Total sales              City
# 0        15.36   Los Angeles, CA
# 1        23.90        Austin, TX
# 2        11.95   Los Angeles, CA
# 3       149.99       Seattle, WA
# 4        11.95       Atlanta, GA

# %%
# Extracting the hours from the Order Date column into an 'Hour' column
merged_data.loc[:,'Hour'] = merged_data['Order Date'].dt.hour
merged_data
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        248151   AA Batteries (4-pack)                 4        3.84
# 1        248152    USB-C Charging Cable                 2       11.95
# 2        248153    USB-C Charging Cable                 1       11.95
# 3        248154        27in FHD Monitor                 1      149.99
# 4        248155    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 185945   150497            20in Monitor                 1      109.99
# 185946   150498        27in FHD Monitor                 1      149.99
# 185947   150499         ThinkPad Laptop                 1      999.99
# 185948   150500  AAA Batteries (4-pack)                 2        2.99
# 185949   150501            Google Phone                 1      600.00
#
#                 Order Date                       Purchase Address  Month  \
# 0      2019-09-17 14:44:00    380 North St, Los Angeles, CA 90001      9
# 1      2019-09-29 10:19:00           511 8th St, Austin, TX 73301      9
# 2      2019-09-16 17:48:00  151 Johnson St, Los Angeles, CA 90001      9
# 3      2019-09-27 07:52:00      355 Hickory St, Seattle, WA 98101      9
# 4      2019-09-01 19:03:00          125 5th St, Atlanta, GA 30301      9
# ...                    ...                                    ...    ...
# 185945 2019-01-26 19:09:00            95 8th St, Dallas, TX 75001      1
# 185946 2019-01-10 22:58:00    403 7th St, San Francisco, CA 94016      1
# 185947 2019-01-21 14:31:00        214 Main St, Portland, OR 97035      1
# 185948 2019-01-15 14:21:00      810 2nd St, Los Angeles, CA 90001      1
# 185949 2019-01-13 16:43:00         428 Cedar St, Boston, MA 02215      1
#
#             Time  Total sales                City  Hour
# 0       14:44:00        15.36     Los Angeles, CA    14
# 1       10:19:00        23.90          Austin, TX    10
# 2       17:48:00        11.95     Los Angeles, CA    17
# 3       07:52:00       149.99         Seattle, WA     7
# 4       19:03:00        11.95         Atlanta, GA    19
# ...          ...          ...                 ...   ...
# 185945  19:09:00       109.99          Dallas, TX    19
# 185946  22:58:00       149.99   San Francisco, CA    22
# 185947  14:31:00       999.99        Portland, OR    14
# 185948  14:21:00         5.98     Los Angeles, CA    14
# 185949  16:43:00       600.00          Boston, MA    16
#
# [185949 rows x 11 columns]

# %%
merged_data.groupby(['Hour']).count()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# 13       12128    12128             12128       12128       12128
# 14       10984    10984             10984       10984       10984
# 15       10175    10175             10175       10175       10175
# 16       10384    10384             10384       10384       10384
# 17       10899    10899             10899       10899       10899
# 18       12280    12280             12280       12280       12280
# 19       12905    12905             12905       12905       12905
# 20       12228    12228             12228       12228       12228
# 21       10921    10921             10921       10921       10921
# 22        8822     8822              8822        8822        8822
# 23        6275     6275              6275        6275        6275
#
#       Purchase Address  Month   Time  Total sales   City
# Hour
# 0                 3910   3910   3910         3910   3910
# 1                 2350   2350   2350         2350   2350
# 2                 1243   1243   1243         1243   1243
# 3                  831    831    831          831    831
# 4                  854    854    854          854    854
# 5                 1321   1321   1321         1321   1321
# 6                 2482   2482   2482         2482   2482
# 7                 4011   4011   4011         4011   4011
# 8                 6256   6256   6256         6256   6256
# 9                 8748   8748   8748         8748   8748
# 10               10944  10944  10944        10944  10944
# 11               12411  12411  12411        12411  12411
# 12               12587  12587  12587        12587  12587
# 13               12128  12128  12128        12128  12128
# 14               10984  10984  10984        10984  10984
# 15               10175  10175  10175        10175  10175
# 16               10384  10384  10384        10384  10384
# 17               10899  10899  10899        10899  10899
# 18               12280  12280  12280        12280  12280
# 19               12905  12905  12905        12905  12905
# 20               12228  12228  12228        12228  12228
# 21               10921  10921  10921        10921  10921
# 22                8822   8822   8822         8822   8822
# 23                6275   6275   6275         6275   6275

# %%
#Visualizing data using a linegraph

hours = [hour for hour, df in merged_data.groupby('Hour')]
plt.figure(figsize=(8,6))
plt.plot(hours, merged_data.groupby(['Hour']).count())
plt.xticks(hours)

plt.grid(True, color='grey')
plt.xlabel('Hours')
plt.ylabel('Number of orders Purchased')
plt.title('Purchases made in Approximated Time Periods')
# Out:
# Text(0.5, 1.0, 'Purchases made in Approximated Time Periods')

# %% [markdown]
# ### Visual interprentation
# #### The graph illustrates that the time intervals from 11 a.m. to 1 p.m. and from 6 p.m. to 8 p.m. are the predominant choices among a majority of clients. Consequently, it is advisable for the business to concentrate its advertising efforts predominantly within these time frames.

# %% [markdown]
# ### Task 4: What products are most often sold together?

# %% [markdown]
# #### Step 1: Let's check which products are ordered together using the order id. Same order id means purcharce items were ordered by the same client

# %%
merged_data.head(50)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    248151       AA Batteries (4-pack)                 4        3.84
# 1    248152        USB-C Charging Cable                 2       11.95
# 2    248153        USB-C Charging Cable                 1       11.95
# 3    248154            27in FHD Monitor                 1      149.99
# 4    248155        USB-C Charging Cable                 1       11.95
# 5    248156      34in Ultrawide Monitor                 1      379.99
# 6    248157    Lightning Charging Cable                 1       14.95
# 7    248158    Lightning Charging Cable                 1       14.95
# 8    248159             Vareebadd Phone                 1      400.00
# 9    248160            Wired Headphones                 1       11.99
# 10   248161        USB-C Charging Cable                 1       11.95
# 11   248162      AAA Batteries (4-pack)                 3        2.99
# 12   248163        USB-C Charging Cable                 1       11.95
# 13   248164            27in FHD Monitor                 1      149.99
# 14   248165    Lightning Charging Cable                 1       14.95
# 15   248166    Apple Airpods Headphones                 1      150.00
# 16   248167                Google Phone                 1      600.00
# 17   248168        USB-C Charging Cable                 1       11.95
# 12  12:32:00        11.95        Portland, OR    12
# 13  15:57:00       149.99   San Francisco, CA    15
# 14  12:42:00        14.95         Atlanta, GA    12
# 15  14:59:00       150.00          Boston, MA    14
# 16  18:52:00       600.00   San Francisco, CA    18
# 17  18:59:00        11.95   San Francisco, CA    18
# 18  19:40:00       109.99   San Francisco, CA    19
# 19  02:01:00         2.99          Boston, MA     2
# 20  15:06:00        11.95   New York City, NY    15
# 21  15:06:00        11.95   New York City, NY    15
# 22  16:49:00        11.99          Boston, MA    16
# 23  20:47:00       150.00         Atlanta, GA    20
# 24  22:57:00        99.99          Dallas, TX    22
# 25  13:58:00       700.00          Austin, TX    13
# 26  13:18:00         7.68   San Francisco, CA    13
# 27  20:36:00        11.95   San Francisco, CA    20
# 28  21:52:00       150.00     Los Angeles, CA    21
# 29  15:06:00       149.99   New York City, NY    15
# 30  15:52:00        11.95   New York City, NY    15
# 31  12:40:00       150.00   New York City, NY    12
# 32  13:03:00       150.00   New York City, NY    13
# 33  17:47:00       379.99   San Francisco, CA    17
# 34  11:23:00         3.84   New York City, NY    11
# 35  15:10:00       379.99   New York City, NY    15
# 36  13:53:00        11.95         Seattle, WA    13
# 37  23:31:00         8.97     Los Angeles, CA    23
# 38  22:17:00       150.00   San Francisco, CA    22
# 39  12:45:00       600.00   San Francisco, CA    12
# 40  21:47:00        99.99   New York City, NY    21
# 41  11:25:00         2.99   San Francisco, CA    11
# 42  09:16:00         5.98          Austin, TX     9
# 43  00:40:00        11.95   San Francisco, CA     0
# 44  20:50:00       109.99          Dallas, TX    20
# 45  23:29:00       999.99          Dallas, TX    23
# 46  21:56:00        14.95          Dallas, TX    21
# 47  19:39:00       150.00        Portland, OR    19
# 48  00:06:00         2.99        Portland, OR     0
# 49  12:47:00       600.00          Boston, MA    12

# %%
df = merged_data[merged_data['Order ID'].duplicated(keep=False)]
df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 20    248171        USB-C Charging Cable                 1       11.95
# 21    248171        USB-C Charging Cable                 1       11.95
# 60    248210                      iPhone                 1      700.00
# 61    248210    Lightning Charging Cable                 1       14.95
# 70    248219  Bose SoundSport Headphones                 1       99.99
# 71    248219                Google Phone                 1      600.00
# 117   248265             Vareebadd Phone                 1      400.00
# 118   248265  Bose SoundSport Headphones                 1       99.99
# 176   248323                Google Phone                 1      600.00
# 177   248323  Bose SoundSport Headphones                 1       99.99
# 183   248329             Vareebadd Phone                 1      400.00
# 184   248329            Wired Headphones                 1       11.99
# 186   248331                      iPhone                 1      700.00
# 187   248331    Lightning Charging Cable                 1       14.95
# 188   248331    Apple Airpods Headphones                 1      150.00
# 238   248381  Bose SoundSport Headphones                 1       99.99
# 239   248381      34in Ultrawide Monitor                 1      379.99
# 265   248407                      iPhone                 1      700.00
# 266   248407    Lightning Charging Cable                 1       14.95
# 267   248407    Apple Airpods Headphones                 1      150.00
#
#              Order Date                            Purchase Address  Month  \
# 20  2019-09-05 15:06:00        705 Hill St, New York City, NY 10001      9
# 177   248323  Bose SoundSport Headphones                 1       99.99
#
#              Order Date                            Purchase Address  Month  \
# 20  2019-09-05 15:06:00        705 Hill St, New York City, NY 10001      9
# 21  2019-09-05 15:06:00        705 Hill St, New York City, NY 10001      9
# 60  2019-09-27 10:33:00  292 Washington St, San Francisco, CA 94016      9
# 61  2019-09-27 10:33:00  292 Washington St, San Francisco, CA 94016      9
# 70  2019-09-24 12:48:00         665 Maple St, Los Angeles, CA 90001      9
# 71  2019-09-24 12:48:00         665 Maple St, Los Angeles, CA 90001      9
# 117 2019-09-24 14:07:00        939 14th St, San Francisco, CA 94016      9
# 118 2019-09-24 14:07:00        939 14th St, San Francisco, CA 94016      9
# 176 2019-09-30 20:36:00             725 10th St, Portland, OR 97035      9
# 177 2019-09-30 20:36:00             725 10th St, Portland, OR 97035      9
#
#          Time  Total sales                City  Hour  \
# 20   15:06:00        11.95   New York City, NY    15
# 21   15:06:00        11.95   New York City, NY    15
# 60   10:33:00       700.00   San Francisco, CA    10
# 61   10:33:00        14.95   San Francisco, CA    10
# 70   12:48:00        99.99     Los Angeles, CA    12
# 71   12:48:00       600.00     Los Angeles, CA    12
# 117  14:07:00       400.00   San Francisco, CA    14
# 118  14:07:00        99.99   San Francisco, CA    14
# 176  20:36:00       600.00        Portland, OR    20
# 177  20:36:00        99.99        Portland, OR    20
#
#                                         Grouped
# 20    USB-C Charging Cable,USB-C Charging Cable
# 21    USB-C Charging Cable,USB-C Charging Cable
# 60              iPhone,Lightning Charging Cable
# 61              iPhone,Lightning Charging Cable
# 70      Bose SoundSport Headphones,Google Phone
# 71      Bose SoundSport Headphones,Google Phone
# 117  Vareebadd Phone,Bose SoundSport Headphones
# 118  Vareebadd Phone,Bose SoundSport Headphones
# 176     Google Phone,Bose SoundSport Headphones
# 177     Google Phone,Bose SoundSport Headphones

# %%
df = df[['Order ID', 'Grouped']].drop_duplicates()
df.head()
# Out:
#     Order ID                                     Grouped
# 20    248171   USB-C Charging Cable,USB-C Charging Cable
# 60    248210             iPhone,Lightning Charging Cable
# 70    248219     Bose SoundSport Headphones,Google Phone
# 117   248265  Vareebadd Phone,Bose SoundSport Headphones
# 176   248323     Google Phone,Bose SoundSport Headphones

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92
